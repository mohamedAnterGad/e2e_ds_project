# %% [markdown]
# ## exploring the data

# %% [markdown]
# ## imports

# %%
import pandas as pd

# %%
pd.read_csv('../data/raw/survey_results_public.csv')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
pd.read_csv('../data/raw/roles_short_names.csv')
# Out:
#                                                                           Original name;Short name
# Developer                                                                     back-end;Back-end dev
# Developer                                                                 full-stack;Full-stack dev
# Developer                                                                   front-end;Front-end dev
# Developer                                            desktop or enterprise applications;Desktop dev
# Developer                                                                         mobile;Mobile dev
# DevOps specialist;DevOps                                                                        NaN
# Database administrator;Database admin                                                           NaN
# Designer;Designer                                                                               NaN
# ...
